# %% [markdown]
# # About Data set
# This data set download from kaggle https://www.kaggle.com/datasets/zusmani/mygenome?select=Child+1+Genome.csv
# Zeeshan-ul-hassan Usmani’s Genome Phenotype SNPs Raw Data
#
# Genomics is a branch of molecular biology that involves structure, function, variation, evolution and mapping of genomes. There are several companies offering next generation sequencing of human genomes from complete 3 billion base-pairs to a few thousand Phenotype SNPs. I’ve used 23andMe (using Illumina HumanOmniExpress-24) for my DNA’s Phenotype SNPs.

# %%
# import libraries
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sns
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r'F:\Data Sceince\Data Sets\Child 1 Genome.csv')

# %%
df.head()
# Out:
#         # rsid chromosome  position genotype
# 0   rs12564807          1    734462       AA
# 1    rs3131972          1    752721       AG
# 2  rs148828841          1    760998       AC
# 3   rs12124819          1    776546       AG
# 4  rs115093905          1    787173       GG

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 601802 entries, 0 to 601801
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   # rsid      601802 non-null  object
#  1   chromosome  601802 non-null  object
#  2   position    601802 non-null  int64
#  3   genotype    601802 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 18.4+ MB

# %%
df.describe()
# Out:
#            position
# count  6.018020e+05
# mean   7.638231e+07
# std    5.698823e+07
# min    3.000000e+00
# 25%    2.981867e+07
# 50%    6.590030e+07
# 75%    1.140182e+08
# max    2.492190e+08

# %%
df.isnull().sum()
# Out:
# # rsid        0
# chromosome    0
# position      0
# genotype      0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 601797    False
# 601798    False
# 601799    False
# 601800    False
# 601801    False
# Length: 601802, dtype: bool

# %%
df.head()
# Out:
#         # rsid chromosome  position genotype
# 0   rs12564807          1    734462       AA
# 1    rs3131972          1    752721       AG
# 2  rs148828841          1    760998       AC
# 3   rs12124819          1    776546       AG
# 4  rs115093905          1    787173       GG

# %% [markdown]
# ## Visualize the number of SNPs per chromosome
# Chromosomes with higher/lower SNP counts indicate regions of dense genetic information or gaps.

# %%
# SNPs distribution
df['chromosome'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ## Identify the frequency of each allele (e.g., A, G, T, C) in the dataset
# This chart shows which alleles are most common in the dataset

# %%
from collections import Counter
import matplotlib.pyplot as plt

# Count alleles
alleles = ''.join(df['genotype'].dropna())
allele_count = Counter(alleles)

# Plot
plt.bar(allele_count.keys(), allele_count.values(), color='skyblue')
plt.xlabel('Alleles')
plt.ylabel('Frequency')
plt.title('Allele Frequency Distribution')
plt.show()

# %% [markdown]
# ## Visualize the number of SNPs per chromosome
# Chromosomes with higher/lower SNP counts indicate regions of dense genetic information or gaps.

# %%
chrom_counts = df['chromosome'].value_counts()

# Bar plot for chromosome distribution
chrom_counts.plot(kind='bar', color='purple', alpha=0.7)
plt.xlabel('Chromosome')
plt.ylabel('Number of SNPs')
plt.title('SNP Distribution Across Chromosomes')
plt.show()

# %% [markdown]
# ## Show proportion of SNPs associated with disease risk.
# This chart highlights what percentage of the genome might contribute to disease susceptibility.

# %%
# Filter disease-related SNPs
risk_snps = df[df['# rsid'] == df['genotype']]

# Create pie chart
labels = ['Risk SNPs', 'Non-Risk SNPs']
sizes = [len(risk_snps), len(df) - len(risk_snps)]
colors = ['red', 'green']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Disease-Associated SNPs')
plt.show()
# This chart highlights what percentage of the genome might contribute to disease susceptibility.

# %% [markdown]
# ## Visualize the frequency of each genotype (e.g., AA, AG, GG).
# This can indicate whether homozygous or heterozygous genotypes are more prevalent.

# %%
genotype_counts = df['genotype'].value_counts()

# Bar plot for genotype counts
genotype_counts.plot(kind='bar', color='orange', alpha=0.8)
plt.xlabel('Genotype')
plt.ylabel('Frequency')
plt.title('Genotype Frequency Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='position', y='chromosome', hue='# rsid', palette='cool', alpha=0.6)
plt.title('Chromosomal SNP Positions')
plt.xlabel('Position on Chromosome')
plt.ylabel('Chromosome')
plt.legend(title='Risk Allele')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "X"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 sns.scatterplot(data=df, x='position', y='chromosome', hue='# rsid', palette='cool', alpha=0.6)
#       3 plt.title('Chromosomal SNP Positions')
#       4 plt.xlabel('Position on Chromosome')
#
# File c:\Users\LENOVO\miniconda3\envs\python_eda\Lib\site-packages\seaborn\relational.py:636, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     633 color = kwargs.pop("color", None)
#     634 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 636 p.plot(ax, kwargs)
#     638 return ax
#
# File c:\Users\LENOVO\miniconda3\envs\python_eda\Lib\site-packages\seaborn\relational.py:404, in _ScatterPlotter.plot(self, ax, kws)
#     400 def plot(self, ax, kws):
#     401
#     402     # --- Determine the visual attributes of the plot
# --> 404     data = self.comp_data.dropna()
#     405     if data.empty:
#     406         return
#
# File c:\Users\LENOVO\miniconda3\envs\python_eda\Lib\site-packages\seaborn\_base.py:1000, in VectorPlotter.comp_data(self)
#     995 if var in self.var_levels:
#     996     # TODO this should happen in some centralized location
#     997     # it is similar to GH2419, but more complicated because
#     998     # supporting `order` in categorical plots is tricky
#     999     orig = orig[orig.isin(self.var_levels[var])]
# -> 1000 comp = pd.to_numeric(converter.convert_units(orig)).astype(float)
#    1001 transform = converter.get_transform().transform
#    1002 parts.append(pd.Series(transform(comp), orig.index, name=orig.name))
#
# File c:\Users\LENOVO\miniconda3\envs\python_eda\Lib\site-packages\pandas\core\tools\numeric.py:232, in to_numeric(arg, errors, downcast, dtype_backend)
#     230 coerce_numeric = errors not in ("ignore", "raise")
#     231 try:
# --> 232     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233         values,
#     234         set(),
#     235         coerce_numeric=coerce_numeric,
#     236         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     237         or isinstance(values_dtype, StringDtype)
#     238         and not values_dtype.storage == "pyarrow_numpy",
#     239     )
#     240 except (ValueError, TypeError):
#     241     if errors == "raise":
#
# File lib.pyx:2433, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "X" at position 574927

# %%
df.head(1)
# Out:
#        # rsid chromosome  position genotype
# 0  rs12564807          1    734462       AA
